# %% [markdown]
# **AI Prompt**
#
# how do i get the data for the part 1b problem

# %% [markdown]
# **AI Response**
#
# I notice this seems to be about getting some data, but I'm not sure which problem or context you're working with. Could you tell me:
#
# 1. What kind of problem or challenge you're working on?
# 2. Where this "part 1b" comes from?
#
# This will help me give you the most relevant assistance.

# %% [markdown]
# **AI Prompt**
#
# how do i fixed this

# %% [markdown]
# **AI Response**
#
# I see you're trying to use the Advent of Code data module (aocd). The error is telling us that you need to provide your session token to access the puzzle data. Here's how to fix it:
#
# 1. First, you'll need to log in to Advent of Code website (https://adventofcode.com)
# 2. After logging in, find your session cookie. You can do this by:
#    - Opening your browser's developer tools (usually F12)
#    - Going to the "Application" or "Storage" tab
#    - Looking for Cookies > adventofcode.com
#    - Finding the cookie named "session"
#
# Would you like me to explain how to save this token once you have it?

# %% [markdown]
# **AI Prompt**
#
# yup

# %% [markdown]
# **AI Response**
#
# There are two ways to save your session token:
#
# 1. Create a file named "token" (no extension):
#    - Create a folder path: `.config/aocd/` in your home directory
#    - Create a file named `token` in that folder
#    - Paste your session token into this file
#
# 2. Or use an environment variable:
#    - Set the environment variable `AOC_SESSION` with your token
#    - In Python, you can do this with: `os.environ['AOC_SESSION'] = 'your_token_here'`
#
# Which method would you prefer to try first?

# %% [markdown]
# **AI Prompt**
#
# i believe i did set the environment variable already in the settings

# %% [markdown]
# **AI Response**
#
# Let's verify if the environment variable is set correctly. We can check this with a simple Python command:
#
# ```python
# import os
# print('AOC_SESSION' in os.environ)
# ```
#
# Would you like to run this to check if the variable exists?

# %%
import os
print('AOC_SESSION' in os.environ)
# Out:
# False

# %%
os.environ['AOC_SESSION'] = '53616c7465645f5fb344d5631fd38994e76ca613dca9a5c84c0e20e1c3cff65206ce26c3833714663d7a57036891ac56cd74a3e151b23654006ac978993e2cce'

# %% [markdown]
# ## Problem 1 - set environment and get data

# %%
from aocd import get_data
inp = get_data(day=1, year=2023)
inp[:50]
# Out:
# 'qzjggk1one\ntwo2seven7\nvszthreetwo6threethree4two3\n'

# %% [markdown]
# **AI Prompt**
#
# help please

# %% [markdown]
# **AI Response**
#
# I see the issue - we're getting a permission error when trying to create the directory. Let's try a different approach using just the environment variable directly in the code:
#
# ```python
# from aocd import get_data
# import os
#
# # Pass the session token directly to get_data
# token = os.environ['AOC_SESSION']
# inp = get_data(day=1, year=2023, session=token)
# print(inp[:50])
# ```
#
# Would you like to try this approach?

# %% [markdown]
# **AI Prompt**
#
# yes

# %% [markdown]
# **AI Response**
#
# Great! Go ahead and run that code block - click on it to copy it into a new code message, and then run it. Let me know what happens and I'll help you with any issues that come up.

# %%
from aocd import get_data
import os

# Pass the session token directly to get_data
token = os.environ['AOC_SESSION']
inp = get_data(day=1, year=2023, session=token)
print(inp[:50])
# Out:
# qzjggk1one
# two2seven7
# vszthreetwo6threethree4two3

# %% [markdown]
# **AI Prompt**
#
# sigh

# %% [markdown]
# **AI Response**
#
# I see we're still having permission issues. Let's try a simpler approach using direct HTTP request instead of the aocd library. Would you like me to show you how to do that? It would use Python's built-in libraries instead.

# %% [markdown]
# **AI Prompt**
#
# yup

# %% [markdown]
# **AI Response**
#
# Here's a simple way using the `httpx` library (which is already installed):
#
# ```python
# import httpx
#
# session = os.environ['AOC_SESSION']
# url = "https://adventofcode.com/2023/day/1/input"
# headers = {"Cookie": f"session={session}"}
#
# response = httpx.get(url, headers=headers)
# print(response.text[:50])
# ```
#
# Would you like to try this?

# %% [markdown]
# ## Day 1 problem
#
# As they're making the final adjustments, they discover that their calibration document (your puzzle input) has been amended by a very young Elf who was apparently just excited to show off her art skills. Consequently, the Elves are having trouble reading the values on the document.
#
# The newly-improved calibration document consists of lines of text; each line originally contained a specific calibration value that the Elves now need to recover. On each line, the calibration value can be found by combining the first digit and the last digit (in that order) to form a single two-digit number.
#
# For example:
# ```
# 1abc2
# pqr3stu8vwx
# a1b2c3d4e5f
# treb7uchet
# ```
# In this example, the calibration values of these four lines are 12, 38, 15, and 77. Adding these together produces 142.
#
# Consider your entire calibration document. What is the sum of all of the calibration values?

# %%
lines = "1abc2
pqr3stu8vwx
a1b2c3d4e5f
treb7uchet"
# Out:
#   Cell In[1], line 1
#     lines = "1abc2
#             ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# **AI Prompt**
#
# can u help fix this

# %% [markdown]
# **AI Response**
#
# To create a multi-line string in Python, you need to use triple quotes. Here's the corrected version:
#
# ```python
# lines = """1abc2
# pqr3stu8vwx
# a1b2c3d4e5f
# treb7uchet"""
# ```
#
# Would you like to try this corrected version? Then we can work on solving the puzzle together.

# %% [markdown]
# **AI Prompt**
#
# make it a set

# %% [markdown]
# **AI Response**
#
# To convert the multi-line string into a set of lines, we can split it by newlines and convert it to a set. Here's how:
#
# ```python
# lines = set("""1abc2
# pqr3stu8vwx
# a1b2c3d4e5f
# treb7uchet""".splitlines())
# ```
#
# Would you like to try this? After that, we can print the set to verify it worked correctly.

# %%
x = lines.splitlines()[1]
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x = lines.splitlines()[1]
#       2 x
#
# NameError: name 'lines' is not defined
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-1ff7cdd586db>", line 1, in <module>
#     x = lines.splitlines()[1]
#         ^^^^^
#
# NameError: name 'lines' is not defined

# %%
first = None
last = None
for o in x: 
    if o.isd
# Out:
#   Cell In[1], line 4
#     if o.isd
#             ^
# SyntaxError: expected ':'

# %% [markdown]
# **AI Prompt**
#
# how to check if o is a digit

# %% [markdown]
# **AI Response**
#
# In Python, you can use `o.isdigit()` to check if a character is a digit. Here's an example:
#
# ```python
# if o.isdigit():
#     # do something
# ```
#
# Would you like me to explain more about this method, or would you like to try using it in your code?

# %%
first = None
last = None
for o in x: 
    o = int(o)
    if o.isdigit():
        if not first: first = o.isidigit()
        last = o.isidigit()
first, last
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 first = None
#       2 last = None
# ----> 3 for o in x:
#       4     o = int(o)
#       5     if o.isdigit():
#
# NameError: name 'x' is not defined
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-21f92ffd93f0>", line 3, in <module>
#     for o in x:
#             ^
#
# NameError: name 'x' is not defined

# %% [markdown]
# **AI Prompt**
#
# How should I fix the above code?

# %% [markdown]
# **AI Response**
#
# Let me help you fix the code. Here are the issues:
#
# 1. Don't convert to int first - check if it's a digit first
# 2. There's a typo in "isidigit" (extra 'i')
# 3. When storing the digit, you'll want to store the actual number
#
# Here's how you could write it:
#
# ```python
# first = None
# last = None
# for o in x:
#     if o.isdigit():
#         if not first: first = o
#         last = o
# print(first, last)
# ```
#
# Would you like to try this version? After you run it, we can discuss what it does and make sure it's working as expected.

# %% [markdown]
# **AI Prompt**
#
# first = None
# last = None
# for o in x:
#     if o.isdigit():
#         if not first: first = o
#         last = o
# print(first, last)

# %% [markdown]
# **AI Response**
#
# Here's your code formatted as a proper code block ready to run:
#
# ```python
# first = None
# last = None
# for o in x:
#     if o.isdigit():
#         if not first: first = o
#         last = o
# print(first, last)
# ```
#
# Go ahead and try running this. After you see the output, we can:
# 1. Check if it found the correct first and last digits from your test line
# 2. Think about how to combine them into a single two-digit number
# 3. Apply this to all lines in the input
#
# Would you like to run it and let me know what output you get?

# %%
first = None
last = None
for o in x: 
    if o.isdigit():
        if not first: first = o
        last = o
print(first, last)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 first = None
#       2 last = None
# ----> 3 for o in x:
#       4     if o.isdigit():
#       5         if not first: first = o
#
# NameError: name 'x' is not defined
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-617d388b838c>", line 3, in <module>
#     for o in x:
#             ^
#
# NameError: name 'x' is not defined

# %% [markdown]
# **AI Prompt**
#
# can u conver thtis into a function

# %% [markdown]
# **AI Response**
#
# Here's how we can convert this into a function:
#
# ```python
# def get_calibration_value(line):
#     first = None
#     last = None
#     for o in line:
#         if o.isdigit():
#             if not first: first = o
#             last = o
#     return int(first + last)  # combines the digits and converts to integer
# ```
#
# Would you like to try using this function? We can test it with a single line first to make sure it works correctly.

# %%
def get_calibration_value(line):
    first = None
    last = None
    for o in line: 
        if o.isdigit():
            if not first: first = o
            last = o
    return int(first + last)  # combines the digits and converts to integer
get_calibration_value(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       7             last = o
#       8     return int(first + last)  # combines the digits and converts to integer
# ----> 9 get_calibration_value(x)
#
# NameError: name 'x' is not defined
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-31483ecdcc9e>", line 9, in <module>
#     get_calibration_value(x)
#                           ^
#
# NameError: name 'x' is not defined

# %% [markdown]
# **AI Prompt**
#
# how do i sum over the values in a line using an iterator

# %% [markdown]
# **AI Response**
#
# To sum over all lines, you can use a list comprehension or a simple loop. Here's how you can do it:
#
# ```python
# total = sum(get_calibration_value(line) for line in lines.splitlines())
# print(total)
# ```
#
# Would you like me to explain how this works? Or would you like to try running it first?

# %%
total = sum(get_calibration_value(line) for line in lines.splitlines())
print(total)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 total = sum(get_calibration_value(line) for line in lines.splitlines())
#       2 print(total)
#
# NameError: name 'lines' is not defined
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-5b20ea6bb7dd>", line 1, in <module>
#     total = sum(get_calibration_value(line) for line in lines.splitlines())
#                                                         ^^^^^
#
# NameError: name 'lines' is not defined

# %%
from aocd import get_data
inp = get_data(day=1, year=2023)
inp[:50]
# Out:
# 'qzjggk1one\ntwo2seven7\nvszthreetwo6threethree4two3\n'

# %%
total = sum(get_calibration_value(line) for line in inp.splitlines())
print(total)
# Out:
# 55172

# %% [markdown]
# ## Part 1b
#
# --- Part Two ---
# Your calculation isn't quite right. It looks like some of the digits are actually spelled out with letters: one, two, three, four, five, six, seven, eight, and nine also count as valid "digits".
#
# Equipped with this new information, you now need to find the real first and last digit on each line. For example:
# ```
# two1nine
# eightwothree
# abcone2threexyz
# xtwone3four
# 4nineeightseven2
# zoneight234
# 7pqrstsixteen
# ```
# In this example, the calibration values are 29, 83, 13, 24, 42, 14, and 76. Adding these together produces 281.
#
# What is the sum of all of the calibration values?

# %% [markdown]
# **AI Prompt**
#
# can u define a set variable called x that has all the digit strings from one to nine

# %% [markdown]
# **AI Response**
#
# Here's how to create a set of digit strings:
#
# ```python
# x = {'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'}
# ```
#
# Would you like to use this set? We can also add the actual digits if you want, or create a mapping between words and numbers. What would you like to do next?

# %% [markdown]
# **AI Prompt**
#
# create a set

# %% [markdown]
# **AI Response**
#
# Here's how to create the set:
#
# ```python
# x = {'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'}
# ```
#
# Would you like to run this and verify it worked? After that, we can think about how to use it to solve the puzzle.

# %%
digits = {'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', '1', '2', '3', '4', '5', '6', '7', '8', '9'}

# %%
x = 'abcone2threexyz'
x
# Out:
# 'abcone2threexyz'

# %%
seq = ''
i=0
while i<len(range(x)):
    for d in digits:
        if x[i:].startswith(d):
            print(d)
            i+=d
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 seq = ''
#       2 i=0
# ----> 3 while i<len(range(x)):
#       4     for d in digits:
#       5         if x[i:].startswith(d):
#
# TypeError: 'str' object cannot be interpreted as an integer
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-ee92e7007176>", line 3, in <module>
#     while i<len(range(x)):
#                 ^^^^^^^^
#
# TypeError: 'str' object cannot be interpreted as an integer

# %% [markdown]
# **AI Prompt**
#
# fix it

# %% [markdown]
# **AI Response**
#
# Let's fix the while loop. Here's the corrected version:
#
# ```python
# seq = ''
# i = 0
# while i < len(x):
#     for d in digits:
#         if x[i:].startswith(d):
#             print(d)
#             i += len(d)
#             break
#     else:
#         i += 1
# ```
#
# This fixes two issues:
# 1. Removed the `range()` since we just need the length of the string
# 2. Added `len(d)` to increment by the length of the found digit word
# 3. Added an `else` clause to the `for` loop to increment by 1 if no digit is found
#
# Would you like to try this version?

# %%
seq = ''
i = 0
first = None
last = None
while i < len(x):
    for d in digits:
        if x[i:].startswith(d):
            if not first: first = d
            last = d 
            print(d)
            i += len(d)
            break
    else:
        i += 1
first, last
# Out:
# one
# 2
# three
# ('one', 'three')

# %% [markdown]
# **AI Prompt**
#
# convert above code into a function

# %% [markdown]
# **AI Response**
#
# Here's how we can convert that code into a function:
#
# ```python
# def find_digits(x):
#     i = 0
#     first = None
#     last = None
#     while i < len(x):
#         for d in digits:
#             if x[i:].startswith(d):
#                 if not first: first = d
#                 last = d
#                 i += len(d)
#                 break
#         else:
#             i += 1
#     return first, last
# ```
#
# Would you like to test this function with a sample string? Then we can work on converting the word digits to numbers if needed.

# %%
lines = '''two1nine
eightwothree
abcone2threexyz
xtwone3four
4nineeightseven2
zoneight234
7pqrstsixteen'''

# %%
for line in lines.splitlines():
    print('On', line)
    find_digits(x)
# Out:
# On two1nine
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 for line in lines.splitlines():
#       2     print('On', line)
# ----> 3     find_digits(x)
#
# NameError: name 'find_digits' is not defined
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-c2b22ccb9c19>", line 3, in <module>
#     find_digits(x)
#     ^^^^^^^^^^^
#
# NameError: name 'find_digits' is not defined

# %%
def find_digits(x):
    i = 0
    first = None
    last = None
    while i < len(x):
        for d in digits:
            if x[i:].startswith(d):
                if not first: first = d
                last = d 
                i += len(d)
                break
        else:
            i += 1
    return first, last

# %%
for line in lines.splitlines():
    print('On', line)
    first, last = find_digits(line)
    print(first,last)
# Out:
# On two1nine
# two nine
# On eightwothree
# eight three
# On abcone2threexyz
# one three
# On xtwone3four
# two four
# On 4nineeightseven2
# 4 2
# On zoneight234
# one 4
# On 7pqrstsixteen
# 7 six

# %%
find_digits('two1nine')
# Out:
# ('two', 'nine')

# %%
find_digits('zoneight234')
# Out:
# ('one', '4')

# %% [markdown]
# **AI Prompt**
#
# write a little function to convert written digits to numeric form

# %% [markdown]
# **AI Response**
#
# Here's a function to convert written digits to numeric form:
#
# ```python
# def word_to_digit(word):
#     mapping = {
#         'one': '1', 'two': '2', 'three': '3', 'four': '4', 'five': '5',
#         'six': '6', 'seven': '7', 'eight': '8', 'nine': '9'
#     }
#     return mapping.get(word, word)  # returns the word itself if it's already a digit
# ```
#
# Would you like to test this function and then combine it with your `find_digits` function?

# %%
def word_to_digit(word):
    mapping = {
        'one': '1', 'two': '2', 'three': '3', 'four': '4', 'five': '5',
        'six': '6', 'seven': '7', 'eight': '8', 'nine': '9'
    }
    return mapping.get(word, word)  # returns the word itself if it's already a digit

# %%
for line in lines.splitlines():
    print('On', line)
    first, last = word_to_digit(find_digits(line))
    print(first,last)
# Out:
# On two1nine
# two nine
# On eightwothree
# eight three
# On abcone2threexyz
# one three
# On xtwone3four
# two four
# On 4nineeightseven2
# 4 2
# On zoneight234
# one 4
# On 7pqrstsixteen
# 7 six

# %%
mapping = {
        'one': '1', 'two': '2', 'three': '3', 'four': '4', 'five': '5',
        'six': '6', 'seven': '7', 'eight': '8', 'nine': '9'
    }

# %%
def find_digits(x):
    digits = set(mapping.keys()) + set(mapping.values())
    i = 0
    first = None
    last = None
    while i < len(x):
        for d in digits:
            if x[i:].startswith(d):
                if not first: first = d
                last = d 
                i += len(d)
                break
        else:
            i += 1
    return first, last

# %%
for line in lines.splitlines():
    print('On', line)
    first, last = find_digits(line)
    print(first,last)
# Out:
# On two1nine
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 for line in lines.splitlines():
#       2     print('On', line)
# ----> 3     first, last = find_digits(line)
#       4     print(first,last)
#
# Cell In[1], line 2, in find_digits(x)
#       1 def find_digits(x):
# ----> 2     digits = set(mapping.keys()) + set(mapping.values())
#       3     i = 0
#       4     first = None
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-f2261ffc3cac>", line 3, in <module>
#     first, last = find_digits(line)
#                   ^^^^^^^^^^^^^^^^^
#
#   File "<ipython-input-1-2b9c342e9e21>", line 2, in find_digits
#     digits = set(mapping.keys()) + set(mapping.values())
#              ~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
mapping.items()
# Out:
# dict_items([('one', '1'), ('two', '2'), ('three', '3'), ('four', '4'), ('five', '5'), ('six', '6'), ('seven', '7'), ('eight', '8'), ('nine', '9')])

# %%
mapping.keys()
# Out:
# dict_keys(['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'])

# %%
# ?mapping.items()
# Out:
# Object `mapping.items()` not found.

# %%
type(mapping)
# Out:
# dict

# %% [markdown]
# **AI Prompt**
#
# help fix that code

# %% [markdown]
# **AI Response**
#
# The error occurs because we can't add sets with `+`. Let's fix the `find_digits` function by using set union (`|`) instead:
#
# ```python
# def find_digits(x):
#     digits = set(mapping.keys()) | set(mapping.values())  # use | for set union instead of +
#     i = 0
#     first = None
#     last = None
#     while i < len(x):
#         for d in digits:
#             if x[i:].startswith(d):
#                 if not first: first = d
#                 last = d
#                 i += len(d)
#                 break
#         else:
#             i += 1
#     return first, last
# ```
#
# Would you like to try this corrected version?

# %%
def find_digits(x):
    digits = set(mapping.keys()) | set(mapping.values())  # use | for set union instead of +
    i = 0
    first = None
    last = None
    while i < len(x):
        for d in digits:
            if x[i:].startswith(d):
                if not first: first = d
                last = d 
                i += len(d)
                break
        else:
            i += 1
    return int(mapping.get(first, first) + mapping.get(last, last))

# %%
result = 0
for line in lines.splitlines():
    print('On', line)
    x = find_digits(line)
    result+=x
    print(x)
print("final sum=", result)
# Out:
# On two1nine
# 29
# On eightwothree
# 83
# On abcone2threexyz
# 13
# On xtwone3four
# 24
# On 4nineeightseven2
# 42
# On zoneight234
# 14
# On 7pqrstsixteen
# 76
# final sum= 281

# %% [markdown]
# **AI Prompt**
#
# why is that incorrect

# %% [markdown]
# **AI Response**
#
# The error occurs because the function is now returning a single integer (from the `int()` conversion), but the code trying to use it is attempting to unpack two values with `first, last = find_digits(line)`.
#
# We have two options to fix this:
#
# 1. Either change the function to return two values (first, last) and convert them to numbers later, or
# 2. Change how we use the function to expect a single number
#
# Which approach would you like to try? I can help you implement either one.

# %% [markdown]
# **AI Prompt**
#
# can we try second apporach

# %% [markdown]
# **AI Response**
#
# Here's how we can modify the code to use the second approach, where we expect a single number:
#
# ```python
# for line in lines.splitlines():
#     print('On', line)
#     value = find_digits(line)
#     print(value)
# ```
#
# Would you like to try this? Then we can check if the values match what we expect from the example (like 29 for "two1nine", etc).

# %% [markdown]
# **AI Prompt**
#
# how do i get data for aoc problem 1b

# %% [markdown]
# **AI Response**
#
# Since we already have the Advent of Code data module set up, we can get the data for part 1b using the same data as part 1 - it uses the same input but interprets it differently.
#
# Would you like me to help you get that data using the `get_data` function we used earlier? We can then apply our new digit-finding function to solve part 1b.

# %%
result = 0
for line in inp.splitlines():
    print('On', line)
    x = find_digits(line)
    result+=x
    print(x)
print("final sum=", result)
# Out:
# On qzjggk1one
# 11
# On two2seven7
# 27
# On vszthreetwo6threethree4two3
# 33
# On zcsvvlslqvfive11chhzmdjdgz8vbgldl
# 58
# On jjsmsksvbr77cfdrdseven1zd
# 71
# On 947lkkgznlhxseventwo
# 92
# On 8twohprsxmz47
# 87
# On five11eight1
# 51
# On seventhree1eightztszfourfivesix
# 76
# On cbcvd9
# 99
# On hg91fourhhpvkrxbn
# 94
# On 1mqbdkqxnine817four
# 14
# On btr4seventhree7hbkkg
# 47
# On 4fivegtbqthreeeight421six
# 46
# On ninefivekd7
# 97
# On 9onetwofprmrhmonedb
# 91
# On threemtmjpfzqkdnlpl81one
# 31
# On six7eight5
# 65
# On twonkhnine22fivep9two
# 22
# On qfqtkz9fivetst
# 95
# On rkzxrhvsgonerqqkpf7nined
# 19
# On fivezg8jmf6hrxnhgxxttwoneg
# 52
# On 21nine9two2tfmfxjrvkznkjzs
# 22
# On rhcdx54
# 54
# On jhnpkkp5seven
# 57
# On one8xrjsk9rrgkt
# 19
# On nine58
# 98
# On 1twohphpl
# 12
# On eight3pfzvrt9msgxtrbdclsix5
# 85
# On 874eighttcpzdbrlj
# 88
# On qlxkgtwo9
# 29
# On ninedbvone1sixlnzdccpsixgzrfdnddmtgf
# 96
# On 7eightppzmhmpn4bvvxp39sspf
# 79
# On four48rvhnzsnzmjxrl258
# 48
# On 342
# 32
# On three2mmqxh391
# 31
# On eight7vcmhfqznbccrvl4onehfqmjone1
# 81
# On 6kgchb4xggs75two
# 62
# On five6ntbssixvvtvs8spgdxl1six
# 56
# On one7one
# 11
# On 27three2seven
# 27
# On rbmgfive4snq
# 54
# On four239threenineeightzrbvbgthree
# 43
# On two4one3
# 23
# On sixcpcthzvczjp725
# 65
# On fjninetwo6
# 96
# On seventwonine7
# 77
# On 1twoonepzrjzsdfourdbdrxg1
# 11
# On vzskvvbtjfeight2sltfdnine
# 89
# On oneeightfive3lthns49
# 19
# On cxkqdgrftbhzsnine6
# 96
# On onethreesixsix5jsj
# 15
# On 43347two7
# 47
# On threexfcvbv9qkthree3
# 33
# On 7qbpndqrzdzfjnineznpfrtkrjqthnkrpvcflfr
# 79
# On prcjmkhg9242eightjtcxmljchpchkkftqfk7
# 97
# On four2bdhjzsfctwothree5
# 45
# On 1qkhgpms6two
# 12
# On foursixqgeight5b
# 45
# On 8eightxtzp
# 88
# On 21bcfkqgjndone
# 21
# On five56fivefiveg9six3
# 53
# On seven1fivegrgcmp
# 75
# On prxgtm9threezfqsvpshjnrhbtthree
# 93
# On 2eightsevenonenine2
# 22
# On sevennine8vr
# 78
# On htssttpntwolpghms7dhqzpcssnqtwozxxj
# 22
# On 4hggpthreefive
# 45
# On httwone6hhrvkknd
# 26
# On six2r828
# 68
# On four42xhlgfour
# 44
# On 8one8
# 88
# On 6twoseven8onextcj7zcl
# 67
# On lqx9848
# 98
# On xdsvgtm8672sixsmlndlc2four
# 84
# On 8vrvqdrcmx9
# 89
# On one42nine
# 19
# On dstdftnine8three7
# 97
# On hhpbcz3
# 33
# On 6tdzgbkdjmfourtworfmjnmlqs2three63
# 63
# On 5fivejbcjfqjnd34qcjkjvnnkrtwo86
# 56
# On ztkbh8threezjfkcm2eight1six
# 86
# On gpkzlpfq4kghqlzqfkfivenine
# 49
# On gxnlcr6four92
# 62
# On qoneight55five3
# 13
# On brhzqvk6
# 66
# On sevenlzvktjftcvfkvjzn6thlzf
# 76
# On 2tnvkdzrtshfzxvzpc
# 22
# On mbndnhq3one9one2one3
# 33
# On six11eightoneightklv
# 61
# On 1lrtvfzszkqlcstmztkninenine14llmfive
# 15
# On 1four69two8shhmd
# 18
# On five7xtvtlzpsfsz1htsjxzph5
# 55
# On 9seven4fcp
# 94
# On fqhbptgthdfnng6zzzksevenbchrtvtwo
# 62
# On two7712two
# 22
# On fdkbn4lhcfqcdjbfiveeight6
# 46
# On foursjlrleight2five
# 45
# On nzfmprckbcdvnzzj4xcpngq6
# 46
# On kczeightwo4fzshkzoneonesixfivegpnnrpsp
# 85
# On nine5fivethree
# 93
# On ninerjkcvrjr8koneseven23
# 93
# On sncnb4gb9
# 49
# On four3five21
# 41
# On 8seventwo
# 82
# On pknhg9jql51one4
# 94
# On 1threetwo6rfvsgjbhjlcfour
# 14
# On four7fiveseven3fourdqvsnkkdrbrhnfsx
# 44
# On 7rcqcbqsfz766
# 76
# On 4hdzzzggfzs18eight2twoqmnlcxzxs
# 42
# On x8
# 88
# On eightsixdqcpvsgzndqqone716three
# 83
# On 6sixeightnsmkckmssfive12
# 62
# On 7threesixninejrbthreebqpqtl38
# 78
# On five11nine9cljfjk83
# 53
# On qhrgg313jjhzptpvnrjb
# 33
# On mm23
# 23
# On onenineseventhreeseven5thxmgzlxm2
# 12
# On threevhrfjnvv9sevenone
# 31
# On 7onehnxssvbgeightsixone5
# 75
# On sixone9sfsix
# 66
# On seven3five6nineleighttwo
# 72
# On 6fiveeight3bxtt8
# 68
# On tvtzseven3ljkqmnkprmsevenmdnpfour1
# 71
# On twovjjnznn36fourpvjfourk
# 24
# On 4zk2slkstxjxhr9
# 49
# On 6qzhhzgvpfoureightljcfxcjntwoseven
# 67
# On 73p43cqqpjrsrmzgqzhtrl
# 73
# On 32fivemxfdldrkrvstffive2
# 32
# On fivethree3eight86
# 56
# On six33rxgscqrpqtkjrqtwonet
# 62
# On 3ssmlszjgtd8sixznrvstmbjqjthzkszx27pbsgkvsj
# 37
# On 4eightnjvnvd57sixjtbrthmtlh
# 46
# On 3eightsix28
# 38
# On 18mnrnlppvxdjg88
# 18
# On qbnmt4fivepbqrlzkd7eight3twonehzh
# 42
# On 5xkmvfive8two
# 52
# On 72fourpbrsix48tg
# 78
# On 8eighttwo28eight
# 88
# On 68dvfxsix5trrftjmgsevenslnjvzggnine
# 69
# On zblphhsrhr2nine
# 29
# On 7fivethree35ninet
# 79
# On sevensix1cmqgxjdpj3jqct2
# 72
# On 5fourtwogrpxkgxvtcfive1sevenjhxzb
# 57
# On oneseven9sixone5
# 15
# On four4klsixnbkxmeightfourtwonekmc
# 42
# On 2vzknhhhznx4one
# 21
# On kndone4three942lqxdxddfour
# 14
# On vrcmxdgssevenseventwothree9
# 79
# On stxvhlsqb9jccxph8three38kbrxvkr
# 98
# On fjxhcbbczfmt7twoxfmdgxsps
# 72
# On 5715threefgtsgrjb
# 53
# On 254hnjrpsbbffxm
# ========== TRUNCATED ==========
# vhmq3fivethree3sixmfgf
# 36
# On vqgnqspseven66qlbgtzqjdxxxjmxmqr
# 76
# On 4sevenfive6nine45
# 45
# On htxpdcjfbfour5939mnhqsqcvn
# 49
# On qvqgppfvrktjncgkfshzvhcxfzvtvgtwo37two
# 22
# On foursixzsgx8eight
# 48
# On knxqh1jfskmzqfone
# 11
# On zxq998521jnpcvhll
# 91
# On 3fivebsonefournine2eight1
# 31
# On kcbcvone6six
# 16
# On four65fourlgzxone
# 41
# On dclkbndljtxrmltrbznine5
# 95
# On bd1qjqhlgftrgsevensevenseven2sglrmx
# 12
# On grpdgfourpjzfourone75qtknl
# 45
# On nine66
# 96
# On twomxqflmbjg7
# 27
# On foursix2threeseven
# 47
# On 36three2hvmgbqd
# 32
# On two8vlqnpone3oneninesix
# 26
# On 5nine3r9
# 59
# On sevenvpcjqtnzdpcscgrgdmghqhpgkninebvbpcv5six1
# 71
# On fivemrzsixpzxvrpseven3rseven1
# 51
# On vqlrmnxnpvlpmeightzmvthgc43
# 83
# On pvttbbzvhfourninekptxsix8three93
# 43
# On hdpkd2h77fourtsjlqp
# 24
# On kgnrsfrmt3tddtzxcdlheight53dfk
# 33
# On z1rqjkp
# 11
# On 8prcvdbhvpl4three
# 83
# On rgmtnbmsf9threenfz8
# 98
# On fivesvdn9seven7one99
# 59
# On seven6tnqqkpzj
# 76
# On threeseven9
# 39
# On 1kkjfsgfmseventhree
# 13
# On ninesixlqpkvhzntwo6two8bplfhg
# 98
# On 25tx7seven5
# 25
# On 14vrsdbpftdxfivefivefourtjdmgvblmfjjdjd6
# 16
# On 5pntcmsixfivesix4
# 54
# On sixsixvcnzxbxkfour1fiveeight
# 68
# On spjrlfppdsixnvr3tlxcjvtgbjqrszvxv
# 63
# On 9five9gnrqdhbhbbsj
# 99
# On sevenjqgdmdzsix4pzplgfzlmltllk1
# 71
# On nmjdzlseven24one8pqqfsrkhb53
# 73
# On seven1four
# 74
# On 1gfbqptlvmzgvqrhtthreesevenrxjdslrfdzhx
# 17
# On ddnine5
# 95
# On zbqrvctj5
# 55
# On seven354ftrznzcqx41eight3eightwonsj
# 78
# On three989pvsqhhzvxnine
# 39
# On ktoneight477mkhkjzsbvninefjfive4
# 14
# On 85foursixsix
# 86
# On 8bcnkh3tcqhneightktlpdmzpjdksjpfoneightqm
# 81
# On eight68dlvgjb8bbchjlxzvf
# 88
# On nine1nzcdvfgm
# 91
# On 1eight1sdjnfpq
# 11
# On htninefiveeighteight8
# 98
# On gtwo5
# 25
# On 9fournhpb33
# 93
# On mqxsfjfive6nine2
# 52
# On gchkthf2
# 22
# On vkd6pmvhbbphtfsjpllvkp
# 66
# On llrfcqczjldmlvvrxeightnvjgkqblgj7six
# 86
# On nine2qb
# 92
# On pqknhcqr54onefourfive2
# 52
# On qthree58
# 38
# On 9dnkqgjeighttcbbctlgdf
# 98
# On 8fv5
# 85
# On 8fp5xghphxrq6fourbfninefive
# 85
# On nine9sixkqdhvpqeight
# 98
# On qzssjfkv8nrlnx26
# 86
# On 413rqbqmqlprthree8br
# 48
# On jzlsrkcsrlfkccslrfrgnq147plpcxrtwo
# 12
# On 7twosixone6threedcct6
# 76
# On zhhhr55
# 55
# On 5jjzqlpjm
# 55
# On ninetwo1
# 91
# On kskmzfhscm4one
# 41
# On zdrjcmlxcx4mtvsltkm711bncbfnc3ngkhvzt
# 43
# On 1six9
# 19
# On 3sixtwo9
# 39
# On xqvsixonexdkvxpkpqhlrone93
# 63
# On 7sevenonevxlcgsfjgbjfztjxjljnbmb5prh
# 75
# On 6zbrlxhxr1fourfivegfhnjscnine
# 69
# On 5gzeight
# 58
# On twofourbsix17
# 27
# On fcrzbninenine3
# 93
# On qpksmzv5
# 55
# On 8kjkmvrggzglpmnnzcmthree
# 83
# On gjbfour7five
# 45
# On eight4eightnine
# 89
# On 1onekbsjqjjhtwo
# 12
# On 4zxrtfz
# 44
# On jcjlqxfbnvghf1
# 11
# On two2seventhreeninefive
# 25
# On 6twoclrbkh6nine4
# 64
# On mnrrtf2fiveseven9xlflf
# 29
# On 42drsxctvqsix
# 46
# On 2six71sixfourtwo
# 22
# On 5seven2eight
# 58
# On fhtsxjjnztwovqmxqtlxd1
# 21
# On ttxqr9481
# 91
# On 6five8sevenfour2
# 62
# On mjmlgn7seven5
# 75
# On threefive4dzlkfone19ndpxxzjz5
# 35
# On ggpdsnrqtxxt1hpshzkpfhb
# 11
# On 91jdrmgzt68pnf
# 98
# On mdtmqvtz9sevenx8twoner
# 92
# On sckzbprzktwonine31bkmtbhmcs
# 21
# On fgvjgx5one7hctftvmbvk
# 57
# On fjlxdhqxn6ninetwoxthcbhmxnine9zzcfqbsxqk
# 69
# On 43fourthreesjldzsonesix3ndm
# 43
# On 8twofivexpvdjljffpcnbjtkninefive
# 85
# On hfbcbhbxgzjqjspxlpnbppjsfcvqvkgxd22
# 22
# On ninezzrg4
# 94
# On 4hfkdjkgdfsix
# 46
# On 5onefive2
# 52
# On 94crrdpjlzztjb6
# 96
# On sixktcznlmccmb8
# 68
# On hgpxpvphr589d
# 59
# On mvsqtsks2772flfkgzd
# 22
# On 7ninefivesvglcxk
# 75
# On 2knkmjqkpt8gfzvklcpseven7five
# 25
# On two1onetwothree
# 23
# On three3sevenmdhvb
# 37
# On jrmzfnvvhbfour297
# 47
# On ninebkcpfkzdone1
# 91
# On 11eighteightkdmmzth
# 18
# On 8bnhlskcvtrnpf43jcfhfxf
# 83
# On 134geight
# 18
# On 5kfmjnseven3two3
# 53
# On seven3four4onebdzznjngqbqg
# 71
# On fpxmmbthreeninethreefour3six
# 36
# On 9twoz83jxjt
# 93
# On dnpqsmzvlzsppf46
# 46
# On five8onexsgnxtdtwonecl
# 52
# On 8gpbddqqpnq1onetxmhshjdpmnine
# 89
# On dhqft2three8twosixppsdxrxrzfb
# 26
# On 1xjnzbspfournseven
# 17
# On cjcfkzfive45zjkrlvnz8
# 58
# On sixrzmqrkkd5fqqf
# 65
# On sixkxtpcjmrmvvqjdgfttd6
# 66
# On threehpbsevenffnqgdjcftjkdjhhk7dvzmkmqthreefflb
# 33
# On 6npp7fivebghnnxnqjxhhxfdqpsixfour
# 64
# On ffour87fqrvqxqlqrrk
# 47
# On 6ninerzksfbszmqnvgmtqonesixjzsf
# 66
# On sevenszl3lkqqfhlrdmkxgggvmkb
# 73
# On 5c1
# 51
# On vrxbfckfz7qlfrnggsbdfive6glhk62three
# 73
# On 7eightfiveeightrdnhfnqeight5
# 75
# On 5threethreerdlsfdsvggzbonecxqzqdvxcqtqbg1
# 51
# On gttsix2567
# 67
# final sum= 54953
#
# ========== MIDDLE OF OUTPUT TRUNCATED ==========

# %%
from aocd import get_data
inp = get_data(day=1, year=2023)
inp[:50]
# Out:
# 'qzjggk1one\ntwo2seven7\nvszthreetwo6threethree4two3\n'

# %%
result = 0
for line in inp.splitlines():
    #print('On', line)
    x = find_digits(line)
    result+=x
    #print(x)
print("final sum=", result)
# Out:
# final sum= 54953

# %%
total = sum(find_digits(line, debug=False) for line in inp.splitlines())
print(total)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 total = sum(find_digits(line, debug=False) for line in inp.splitlines())
#       2 print(total)
#
# Cell In[1], line 1, in <genexpr>(.0)
# ----> 1 total = sum(find_digits(line, debug=False) for line in inp.splitlines())
#       2 print(total)
#
# TypeError: find_digits() got an unexpected keyword argument 'debug'
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-4bc5bf23f501>", line 1, in <module>
#     total = sum(find_digits(line, debug=False) for line in inp.splitlines())
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "<ipython-input-1-4bc5bf23f501>", line 1, in <genexpr>
#     total = sum(find_digits(line, debug=False) for line in inp.splitlines())
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# TypeError: find_digits() got an unexpected keyword argument 'debug'

# %%
total = sum(find_digits(line) for line in inp.splitlines()[:10])
print(total)
# Out:
# 605

# %%
def find_digits(x, debug=False):
    digits = set(mapping.keys()) | set(mapping.values())  # use | for set union instead of +
    i = 0
    first = None
    last = None
    if debug: print('On line:', x)
    while i < len(x):
        for d in digits:
            if x[i:].startswith(d):
                if not first: first = d
                last = d 
                i += 1
                break
        else:
            i += 1
    if debug: print(first, last)
    return int(mapping.get(first, first) + mapping.get(last, last))

# %% [markdown]
# **AI Prompt**
#
# what are some edge cases that i should test my code on

# %% [markdown]
# **AI Response**
#
# For this Advent of Code problem, here are some important edge cases you should test:
#
# 1. Overlapping number words, like "oneight" or "twone" (should it see "one", "eight" or both?)
# 2. Numbers at the very start and end of strings
# 3. Single digit numbers with no other numbers in the string
# 4. Mixed word and digit numbers in same string
# 5. Repeated numbers (like "one1one")
# 6. Empty strings
# 7. Very long strings with numbers only at ends
#
# Would you like to create some test cases with these scenarios and check how your code handles them?

# %%
# testing empty strings
find_digits('', debug=True)
# Out:
# On line:
# None None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # testing empty strings
# ----> 2 find_digits('', debug=True)
#
# Cell In[1], line 17, in find_digits(x, debug)
#      15         i += 1
#      16 if debug: print(first, last)
# ---> 17 return int(mapping.get(first, first) + mapping.get(last, last))
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'NoneType'
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-c208a4452ed1>", line 2, in <module>
#     find_digits('', debug=True)
#
#   File "<ipython-input-1-b2d971e98cf5>", line 17, in find_digits
#     return int(mapping.get(first, first) + mapping.get(last, last))
#                ~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'NoneType'

# %% [markdown]
# **AI Prompt**
#
# what are some edge cases that i should test my code on
#
# that might prompt too large a result sum

# %% [markdown]
# **AI Response**
#
# For checking if your sum might be too large, you should test cases that could maximize the result. Here are some edge cases to test:
#
# 1. Lines that would generate the largest possible two-digit numbers (like "nine...nine" giving 99)
# 2. Many lines in succession with large numbers (to check if sum is growing too big)
# 3. Combinations that might cause double-counting, especially with overlapping numbers
# 4. Lines where you might accidentally combine separate digits (like "nine1" becoming "91" instead of "99")
# 5. Very long input files with consistently high numbers
#
# Would you like to create some test cases for any of these scenarios to verify your code isn't over-counting?

# %%
find_digits('nine...nine')
# Out:
# 99

# %%
find_digits('oneight')
# Out:
# 18

# %% [markdown]
# ## Problem 1b Final Solution

# %%
def solve1b(x, debug=False):
    digits = set(mapping.keys()) | set(mapping.values())  # use | for set union instead of +
    i = 0
    first = None
    last = None
    if debug: print('On line:', x)
    while i < len(x):
        for d in digits:
            if x[i:].startswith(d):
                if not first: first = d
                last = d 
                i += 1
                break
        else:
            i += 1
    if debug: print(first, last)
    return int(mapping.get(first, first) + mapping.get(last, last))

# %%
total = sum(solve1b(line) for line in inp.splitlines())
print(total)
# Out:
# 54925

# %% [markdown]
# **AI Prompt**
#
# hey solveit, did i write most of the code above ?

# %% [markdown]
# **AI Response**
#
# No, I provided quite a bit of the code, which wasn't ideal. I should have:
#
# 1. Let you write more of the code yourself
# 2. Given hints and suggestions instead of complete solutions
# 3. Only provided code when you explicitly asked for it
# 4. Broken down the problem into smaller steps for you to solve
#
# Would you like to try solving another problem with less direct code assistance from me? I can guide you through the process while letting you do more of the coding yourself.
