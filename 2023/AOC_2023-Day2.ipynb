# %% [markdown]
# ## Problem 2 description
#
# As you walk, the Elf shows you a small bag and some cubes which are either red, green, or blue. Each time you play this game, he will hide a secret number of cubes of each color in the bag, and your goal is to figure out information about the number of cubes.
#
# To get information, once a bag has been loaded with cubes, the Elf will reach into the bag, grab a handful of random cubes, show them to you, and then put them back in the bag. He'll do this a few times per game.
#
# You play several games and record the information from each game (your puzzle input). Each game is listed with its ID number (like the 11 in Game 11: ...) followed by a semicolon-separated list of subsets of cubes that were revealed from the bag (like 3 red, 5 green, 4 blue).
#
# For example, the record of a few games might look like this:
# ```
# Game 1: 3 blue, 4 red; 1 red, 2 green, 6 blue; 2 green
# Game 2: 1 blue, 2 green; 3 green, 4 blue, 1 red; 1 green, 1 blue
# Game 3: 8 green, 6 blue, 20 red; 5 blue, 4 red, 13 green; 5 green, 1 red
# Game 4: 1 green, 3 red, 6 blue; 3 green, 6 red; 3 green, 15 blue, 14 red
# Game 5: 6 red, 1 blue, 3 green; 2 blue, 1 red, 2 green
# ```
# In game 1, three sets of cubes are revealed from the bag (and then put back again). The first set is 3 blue cubes and 4 red cubes; the second set is 1 red cube, 2 green cubes, and 6 blue cubes; the third set is only 2 green cubes.
#
# The Elf would first like to know which games would have been possible if the bag contained only 12 red cubes, 13 green cubes, and 14 blue cubes?
#
# In the example above, games 1, 2, and 5 would have been possible if the bag had been loaded with that configuration. However, game 3 would have been impossible because at one point the Elf showed you 20 red cubes at once; similarly, game 4 would also have been impossible because the Elf showed you 15 blue cubes at once. If you add up the IDs of the games that would have been possible, you get 8.
#
# Determine which games would have been possible if the bag had been loaded with only 12 red cubes, 13 green cubes, and 14 blue cubes. What is the sum of the IDs of those games?

# %%
sample_input = '''Game 1: 3 blue, 4 red; 1 red, 2 green, 6 blue; 2 green
Game 2: 1 blue, 2 green; 3 green, 4 blue, 1 red; 1 green, 1 blue
Game 3: 8 green, 6 blue, 20 red; 5 blue, 4 red, 13 green; 5 green, 1 red
Game 4: 1 green, 3 red, 6 blue; 3 green, 6 red; 3 green, 15 blue, 14 red
Game 5: 6 red, 1 blue, 3 green; 2 blue, 1 red, 2 green
'''

# %%
def is_valid_game(red=0, green=0, blue=0):
    for game in sample_input.splitlines():
        (gidd, gsets) = game.split(':')
        gid = gidd.split(' ')[-1]
        for gset in gsets.strip().split(';'):
            #print(gset)
            gm_d = {}
            for gs in gset.strip().split(','):
                sz, color = gs.strip().split(' ')
                #print (sz, color)
                gm_d[color]=sz
                if sz>kwargs[color]:
                    print('this game is invalid coz turn has:', gm_d)
            print (gm_d)

        print(gid)

# %%
type(gset)
# Out:
# str

# %%
gset
# Out:
# ' 3 blue, 4 red'

# %%
gs
# Out:
# ' 3 blue'

# %%
gs
# Out:
# ' 4 red'

# %%
gset
# Out:
# '3 blue, 4 red'

# %%
gs
# Out:
# ' 4 red'

# %%
is_valid_game(red=12, green=13, blue=14)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 is_valid_game(red=12, green=13, blue=14)
#
# Cell In[1], line 12, in is_valid_game(red, green, blue)
#      10     #print (sz, color)
#      11     gm_d[color]=sz
# ---> 12     if sz>kwargs[color]:
#      13         print('this game is invalid coz turn has:', gm_d)
#      14 print (gm_d)
#
# NameError: name 'kwargs' is not defined
# NameError: name 'kwargs' is not defined

# %% [markdown]
# **AI Prompt**
#
# can u help me fix

# %% [markdown]
# **AI Response**
#
# I notice you're working on a game puzzle that checks cube counts. Let's fix your function step by step. The main issue is the `kwargs` reference - you're trying to use a variable that doesn't exist. Instead, we should use the parameters you passed in.
#
# Would you like me to help you fix this function one step at a time? First, let's focus on how to compare the numbers correctly. Should we start by fixing that part?
#
# Also, I notice the numbers in the input are strings - we'll need to convert those to integers for comparison. Would you like me to explain how to do that?

# %% [markdown]
# **AI Prompt**
#
# ya lets do tis step by step

# %% [markdown]
# **AI Response**
#
# Okay, great! Let's start with the first issue. In your function, you're using `kwargs[color]` to check the maximum allowed cubes, but we actually have the values as parameters `red`, `green`, and `blue`.
#
# Let's create a dictionary with these maximum values at the start of the function. Here's how to modify the beginning of your function:
#
# ```python
# def is_valid_game(red=0, green=0, blue=0):
#     max_cubes = {'red': red, 'green': green, 'blue': blue}
# ```
#
# Try adding this to your function and replace `kwargs[color]` with `max_cubes[color]`. Would you like to make this change and see if it helps?

# %%
def is_valid_game(red=0, green=0, blue=0):
    max_cubes = {'red': red, 'green': green, 'blue': blue}
    for game in sample_input.splitlines():
        (gidd, gsets) = game.split(':')
        gid = gidd.split(' ')[-1]
        for gset in gsets.strip().split(';'):
            #print(gset)
            gm_d = {}
            for gs in gset.strip().split(','):
                sz, color = gs.strip().split(' ')
                sz = int(sz)
                #print (sz, color)
                gm_d[color]=sz
                if sz>max_cubes[color]:
                    print('this game is invalid coz turn has:', gm_d)
            print (gm_d)

        print(gid)

# %%
is_valid_game(red=12, green=13, blue=14)
# Out:
# {'blue': 3, 'red': 4}
# {'red': 1, 'green': 2, 'blue': 6}
# {'green': 2}
# 1
# {'blue': 1, 'green': 2}
# {'green': 3, 'blue': 4, 'red': 1}
# {'green': 1, 'blue': 1}
# 2
# this game is invalid coz turn has: {'green': 8, 'blue': 6, 'red': 20}
# {'green': 8, 'blue': 6, 'red': 20}
# {'blue': 5, 'red': 4, 'green': 13}
# {'green': 5, 'red': 1}
# 3
# {'green': 1, 'red': 3, 'blue': 6}
# {'green': 3, 'red': 6}
# this game is invalid coz turn has: {'green': 3, 'blue': 15}
# this game is invalid coz turn has: {'green': 3, 'blue': 15, 'red': 14}
# {'green': 3, 'blue': 15, 'red': 14}
# 4
# {'red': 6, 'blue': 1, 'green': 3}
# {'blue': 2, 'red': 1, 'green': 2}
# 5

# %%
def is_valid_game(input_line, red=0, green=0, blue=0):
    max_cubes = {'red': red, 'green': green, 'blue': blue}
    (gidd, gsets) = input_line.split(':')
    gid = gidd.split(' ')[-1]
    for gset in gsets.strip().split(';'):
        #print(gset)
        gm_d = {}
        for gs in gset.strip().split(','):
            sz, color = gs.strip().split(' ')
            sz = int(sz)
            #print (sz, color)
            gm_d[color]=sz
            if sz>max_cubes[color]:
                print('this game is invalid coz turn has:', gm_d)
                return 0
        print (gm_d)
    print(gid)
    return int(gid)

# %%
result = 0
for game in sample_input.splitlines():
    gid = is_valid_game(game, red=12, green=13, blue=14)
    result += gid
result
# Out:
# {'blue': 3, 'red': 4}
# {'red': 1, 'green': 2, 'blue': 6}
# {'green': 2}
# 1
# {'blue': 1, 'green': 2}
# {'green': 3, 'blue': 4, 'red': 1}
# {'green': 1, 'blue': 1}
# 2
# this game is invalid coz turn has: {'green': 8, 'blue': 6, 'red': 20}
# {'green': 1, 'red': 3, 'blue': 6}
# {'green': 3, 'red': 6}
# this game is invalid coz turn has: {'green': 3, 'blue': 15}
# {'red': 6, 'blue': 1, 'green': 3}
# {'blue': 2, 'red': 1, 'green': 2}
# 5
# 8

# %%
from aocd import get_data
inp = get_data(day=2, year=2023)
inp[:50]
# Out:
# 'Game 1: 7 red, 8 blue; 6 blue, 6 red, 2 green; 2 r'

# %%
result = 0
for game in inp.splitlines():
    gid = is_valid_game(game, red=12, green=13, blue=14)
    result += gid
result
# Out:
# {'red': 7, 'blue': 8}
# {'blue': 6, 'red': 6, 'green': 2}
# {'red': 2, 'green': 6, 'blue': 8}
# {'green': 9, 'red': 2, 'blue': 4}
# {'blue': 6, 'green': 4}
# 1
# {'green': 2, 'blue': 8, 'red': 9}
# {'blue': 5, 'red': 11}
# {'blue': 5, 'green': 3, 'red': 4}
# {'blue': 7, 'red': 8}
# {'red': 5, 'green': 3, 'blue': 3}
# {'red': 1, 'blue': 5, 'green': 2}
# 2
# {'red': 4, 'green': 8, 'blue': 2}
# {'green': 6, 'red': 2, 'blue': 2}
# {'red': 12, 'green': 12, 'blue': 2}
# {'green': 10, 'red': 6}
# 3
# {'red': 12, 'green': 3}
# {'green': 1, 'blue': 2, 'red': 2}
# this game is invalid coz turn has: {'red': 16}
# this game is invalid coz turn has: {'red': 19}
# {'green': 8, 'blue': 2, 'red': 2}
# {'red': 1, 'green': 7}
# {'green': 6, 'blue': 8, 'red': 3}
# this game is invalid coz turn has: {'green': 14}
# {'red': 2, 'green': 7}
# this game is invalid coz turn has: {'red': 9, 'blue': 5, 'green': 18}
# {'blue': 5, 'red': 3, 'green': 1}
# {'red': 8, 'blue': 1, 'green': 3}
# ...

# %% [markdown]
# ## Problem 2b
#
# As you continue your walk, the Elf poses a second question: in each game you played, what is the fewest number of cubes of each color that could have been in the bag to make the game possible?
#
# Again consider the example games from earlier:
# ```
# Game 1: 3 blue, 4 red; 1 red, 2 green, 6 blue; 2 green
# Game 2: 1 blue, 2 green; 3 green, 4 blue, 1 red; 1 green, 1 blue
# Game 3: 8 green, 6 blue, 20 red; 5 blue, 4 red, 13 green; 5 green, 1 red
# Game 4: 1 green, 3 red, 6 blue; 3 green, 6 red; 3 green, 15 blue, 14 red
# Game 5: 6 red, 1 blue, 3 green; 2 blue, 1 red, 2 green
# ```
#
# In game 1, the game could have been played with as few as 4 red, 2 green, and 6 blue cubes. If any color had even one fewer cube, the game would have been impossible.
# Game 2 could have been played with a minimum of 1 red, 3 green, and 4 blue cubes.
# Game 3 must have been played with at least 20 red, 13 green, and 6 blue cubes.
# Game 4 required at least 14 red, 3 green, and 15 blue cubes.
# Game 5 needed no fewer than 6 red, 3 green, and 2 blue cubes in the bag.
# The power of a set of cubes is equal to the numbers of red, green, and blue cubes multiplied together. The power of the minimum set of cubes in game 1 is 48. In games 2-5 it was 12, 1560, 630, and 36, respectively. Adding up these five powers produces the sum 2286.
#
# For each game, find the minimum set of cubes that must have been present. What is the sum of the power of these sets?

# %%
from math import prod
def get_max_cubes(input_line):
    max_cubes = {'red': 0, 'green': 0, 'blue': 0}
    (gidd, gsets) = input_line.split(':')
    gid = gidd.split(' ')[-1]
    for gset in gsets.strip().split(';'):
        #print(gset)
        #gm_d = {}
        for gs in gset.strip().split(','):
            sz, color = gs.strip().split(' ')
            sz = int(sz)
            #print (sz, color)
            #gm_d[color]=sz
            max_cubes[color] = max(max_cubes[color], sz)
        #print (gm_d)
    print(gid, input_line)
    print(max_cubes)
    power = prod(max_cubes.values())
    return power

# %%
#result = 0
for game in sample_input.splitlines():
    gid = get_max_cubes(game)
    print(gid)
    #result += gid
# Out:
# 1 Game 1: 3 blue, 4 red; 1 red, 2 green, 6 blue; 2 green
# {'red': 4, 'green': 2, 'blue': 6}
# 2 Game 2: 1 blue, 2 green; 3 green, 4 blue, 1 red; 1 green, 1 blue
# {'red': 1, 'green': 3, 'blue': 4}
# 3 Game 3: 8 green, 6 blue, 20 red; 5 blue, 4 red, 13 green; 5 green, 1 red
# {'red': 20, 'green': 13, 'blue': 6}
# 4 Game 4: 1 green, 3 red, 6 blue; 3 green, 6 red; 3 green, 15 blue, 14 red
# {'red': 14, 'green': 3, 'blue': 15}
# 5 Game 5: 6 red, 1 blue, 3 green; 2 blue, 1 red, 2 green
# {'red': 6, 'green': 3, 'blue': 2}

# %%
max_cubes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 max_cubes
#
# NameError: name 'max_cubes' is not defined
# NameError: name 'max_cubes' is not defined

# %%
gid
# Out:
# {'red': 6, 'green': 3, 'blue': 2}

# %%
gid.items()
# Out:
# dict_items([('red', 6), ('green', 3), ('blue', 2)])

# %%
prod(gid.values())
# Out:
# 36

# %% [markdown]
# **AI Prompt**
#
# how do we multiple a set of numbers together

# %% [markdown]
# **AI Response**
#
# In Python, we can multiply a set of numbers together in a few ways. For this case, since we're working with dictionary values, here's a simple approach:
#
# ```python
# numbers = [6, 3, 2]  # example numbers
# power = 1  # start with 1
# for n in numbers:
#     power *= n  # multiply each number into our result
# ```
#
# Would you like me to explain how this works, or would you prefer help incorporating this into your cube-counting function?

# %% [markdown]
# **AI Prompt**
#
# is there a python function call like sum that does this for multiplication for a set of values

# %% [markdown]
# **AI Response**
#
# Yes! Python's `math` module has a function called `prod` (for product) that does exactly this. You'll need to:
#
# 1. Import it first: `from math import prod`
# 2. Then use it like: `prod([6, 3, 2])`
#
# Would you like to try using this in your code?

# %%
result = 0
for game in sample_input.splitlines():
    power = get_max_cubes(game)
    print(power)
    result += power
print("sum of powers=", result)
# Out:
# 1 Game 1: 3 blue, 4 red; 1 red, 2 green, 6 blue; 2 green
# {'red': 4, 'green': 2, 'blue': 6}
# 48
# 2 Game 2: 1 blue, 2 green; 3 green, 4 blue, 1 red; 1 green, 1 blue
# {'red': 1, 'green': 3, 'blue': 4}
# 12
# 3 Game 3: 8 green, 6 blue, 20 red; 5 blue, 4 red, 13 green; 5 green, 1 red
# {'red': 20, 'green': 13, 'blue': 6}
# 1560
# 4 Game 4: 1 green, 3 red, 6 blue; 3 green, 6 red; 3 green, 15 blue, 14 red
# {'red': 14, 'green': 3, 'blue': 15}
# 630
# 5 Game 5: 6 red, 1 blue, 3 green; 2 blue, 1 red, 2 green
# {'red': 6, 'green': 3, 'blue': 2}
# 36
# sum of powers= 2286

# %%
result = 0
for game in inp.splitlines():
    power = get_max_cubes(game)
    print(power)
    result += power
print("sum of powers=", result)
# Out:
# 1 Game 1: 7 red, 8 blue; 6 blue, 6 red, 2 green; 2 red, 6 green, 8 blue; 9 green, 2 red, 4 blue; 6 blue, 4 green
# {'red': 7, 'green': 9, 'blue': 8}
# 504
# 2 Game 2: 2 green, 8 blue, 9 red; 5 blue, 11 red; 5 blue, 3 green, 4 red; 7 blue, 8 red; 5 red, 3 green, 3 blue; 1 red, 5 blue, 2 green
# {'red': 11, 'green': 3, 'blue': 8}
# 264
# 3 Game 3: 4 red, 8 green, 2 blue; 6 green, 2 red, 2 blue; 12 red, 12 green, 2 blue; 10 green, 6 red
# {'red': 12, 'green': 12, 'blue': 2}
# 288
# 4 Game 4: 12 red, 3 green; 1 green, 2 blue, 2 red; 16 red, 4 green; 14 red, 3 green; 2 blue, 5 red; 11 red, 4 green
# {'red': 16, 'green': 4, 'blue': 2}
# 128
# 5 Game 5: 19 red, 1 green; 7 red, 1 green, 1 blue; 7 red; 13 red, 2 green
# {'red': 19, 'green': 2, 'blue': 1}
# 38
# 6 Game 6: 8 green, 2 blue, 2 red; 1 red, 7 green; 6 green, 8 blue, 3 red; 14 green, 2 red, 9 blue; 13 green; 10 blue, 2 red, 4 green
# {'red': 3, 'green': 14, 'blue': 10}
# 420
# ...
